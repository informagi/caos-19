# %%
import xml.etree.ElementTree as Et

from pyserini.search import pysearch
from pyserini.search import pyquerybuilder
from tqdm import tqdm
from collections import defaultdict
from pprint import pprint

import subprocess

from pyserini.pyclass import autoclass
from pyserini.analysis.pyanalysis import get_lucene_analyzer

# %%
searcher = pysearch.SimpleSearcher('/home/chris/data/anserini/lucene-index-cord19-paragraph-2020-05-01/')

# %%
docid_path = 'docids-rnd2.txt'
valid = set()
with open(docid_path, 'r') as f:
    for line in f:
        valid |= {line.strip()}

# %%
topics_path = '/home/chris/data/topics/topics-rnd2.xml'
qrel_path = '/home/chris/data/qrels/qrels-rnd1.txt'

# %%
tree = Et.parse(topics_path)
root = tree.getroot()
topics = [root[i][0].text for i in range(35)]
nars =  [root[i][1].text for i in range(35)]

# %%
judged = defaultdict(set)
with open(qrel_path, 'r') as f:
    for line in f:
        topicno, iteration, empty, docid, relevance = line.strip().split(' ')
        judged[int(topicno)] |= {docid}

# %%
tasks = [
    ['environmental transmission', 'incubation', 'contagious', 'persistence', 'stability', 'physical', 'weather',
     'epidemiology', 'shedding', 'reproductive number', 'modes of transmission', 'virulent', 'asymptomatic', 'pathogen',
     'evolutionary host', 'transmission host'],
    ['smoking', 'risk', 'pulmonary', 'pre-condition', 'co-infection', 'high-risk', 'severe', 'susceptible', 'fatality',
     'neonates', 'respitory', 'condition', 'pre-existing', 'pregnant', 'morbidities'],
    ['human-animal', 'origin', 'genetics', 'evolution', 'genome', 'sample sets', 'genomic', 'strain', 'livestock',
     'animal host', 'natural history', 'genetic drift', 'mutation', 'genomics', 'sequencing'],
    ['vaccine', 'therapeutic', 'treat', 'drugs', 'pharmaceuticals', 'recipients', 'ADE', 'complication', 'antiviral',
     'prophylaxis', 'cloroquine', 'vaccination', 'immume respone'],
    ['medical care', 'surge capacity', 'nursing home', 'allocation', 'personal protective equirement',
     'clinical characterization', 'nursing', 'care', 'Extracorporeal membrane oxygenation', 'ECMO',
     'mechanical ventilation', 'extrapulmonary manifestations', 'cardiomyopathy', 'cardiac arrest',
     'regulatory standards', 'N95 masks', 'elastomeric respirators', 'telemedicine', 'steroids', 'high flow oxygen',
     'supportive interventions'],
    ['NPI', 'non-pharmaceutical intervention', 'school closure', 'travel ban', 'quarantine', 'mass gathering',
     'social distancing', 'public health advice', 'economic impact'],
    ['counties', 'geographic', 'geography', 'mortality rate', 'spread', 'mutations'],
    ['diagnostic', 'surveillance', 'detection', 'screening', 'ELISAs', 'capacity', 'testing', 'point-of-care',
     'rapid testing', 'pathogen', 'reagent', 'cytokines', 'response markers', 'swabs'],
    ['ethical', 'social science', 'principles', 'standards', 'ethics', 'psychological health', 'fear', 'anxiety',
     'stigma', 'sociology'],
    ['collaboration', 'nomenclature', 'data standards', 'information sharing', 'communication', 'collaborate',
     'coordination', 'misunderstanding', 'action plan']
]

topic_task_no = [2,0,3,0,3,6,3,6,7,5,4,5,0,0,0,0,3,5,5,1,0,0,1,1,6,6,6,3,3,3,2,2,3,1,9]

# %%
stops = {'of', 'to', 'the', 'for', 'in', 'on', 'and'}

def build_query(original, extension, extension_split):
    original = [o for o in original if o not in stops]
    extension = [e for e in extension if e not in stops]
    original_split = 1 - extension_split
    builder = pyquerybuilder.get_boolean_query_builder()
    for o in original:
        o = pyquerybuilder.get_term_query(o)
        boostquery = pyquerybuilder.get_boost_query(o, original_split/len(original))
        builder.add(boostquery, pyquerybuilder.JBooleanClauseOccur['should'].value)
    for e in extension:
        e = pyquerybuilder.get_term_query(e)
        boostquery = pyquerybuilder.get_boost_query(e, extension_split/len(extension))
        builder.add(boostquery, pyquerybuilder.JBooleanClauseOccur['should'].value)
    return builder.build()

# %%
split = .2
qrel_seen = 0
total = 0
filename = f'ru-t-exp-rnd2.run' 
with open(filename, 'w') as f:
    for topicno, topic in tqdm(enumerate(topics)):
        task = tasks[topic_task_no[topicno]]
        topic = topic.split(' ')
        new_task = []
        for t in task:
            for nt in t.split(' '):
                new_task.append(nt)
        task = new_task
        query = build_query(topic, task, split)
        hits = searcher.search(query, 5000)
        i = 0
        j = 0
        seen = set()
        while i < 100:
            hit = hits[j]
            if hit.docid.split('.')[0] in seen or hit.docid.split('.')[0] in judged[topicno+1] or hit.docid.split('.')[0] not in valid:
                j+=1
                continue
            f.write(f'{topicno+1} Q0 {hit.docid.split(".")[0]} {i+1} {hit.score} {filename[:-4]}\n')
            i+=1
            j+=1
            seen |= {hit.docid.split('.')[0]}

            if hit.docid.split('.')[0] in judged[topicno+1]:
                qrel_seen +=1
            total+=1
# Out:
# 35it [00:59,  1.56s/it]

# %%
qrel_seen
# Out:
# 0

# %%
# !head -n 30 ru-t-exp-rnd2.run
# Out:
# 1 Q0 sqrn6kjy 1 1.8131999969482422 ru-t-exp-rnd2
# 1 Q0 ne5r4d4b 2 1.7706999778747559 ru-t-exp-rnd2
# 1 Q0 2054tkb7 3 1.7668999433517456 ru-t-exp-rnd2
# 1 Q0 d6by9p41 4 1.7547999620437622 ru-t-exp-rnd2
# 1 Q0 zqf351sv 5 1.7525999546051025 ru-t-exp-rnd2
# 1 Q0 4iwddq2u 6 1.7404999732971191 ru-t-exp-rnd2
# 1 Q0 jr255dwn 7 1.722100019454956 ru-t-exp-rnd2
# 1 Q0 djclli8n 8 1.7196999788284302 ru-t-exp-rnd2
# 1 Q0 imvbkt69 9 1.7128000259399414 ru-t-exp-rnd2
# 1 Q0 431ksdno 10 1.7055000066757202 ru-t-exp-rnd2
# 1 Q0 m8jf9n6x 11 1.7034000158309937 ru-t-exp-rnd2
# 1 Q0 wuegn0jg 12 1.7009999752044678 ru-t-exp-rnd2
# 1 Q0 pwvcwlh8 13 1.7000000476837158 ru-t-exp-rnd2
# 1 Q0 9sofxhj7 14 1.6996999979019165 ru-t-exp-rnd2
# 1 Q0 xxblr8qd 15 1.6959999799728394 ru-t-exp-rnd2
# 1 Q0 9dwpnvxf 16 1.690500020980835 ru-t-exp-rnd2
# 1 Q0 58hjolfz 17 1.687399983406067 ru-t-exp-rnd2
# 1 Q0 6pbaa6u4 18 1.6827991008758545 ru-t-exp-rnd2
# 1 Q0 rq9hmjsx 19 1.6825000047683716 ru-t-exp-rnd2
# 1 Q0 zcy4hpqp 20 1.6821000576019287 ru-t-exp-rnd2
# 1 Q0 h8cemq2n 21 1.6789000034332275 ru-t-exp-rnd2
# 1 Q0 bo104j2y 22 1.670199990272522 ru-t-exp-rnd2
# 1 Q0 qxkxjxsz 23 1.6679999828338623 ru-t-exp-rnd2
# 1 Q0 3dlukfho 24 1.667799949645996 ru-t-exp-rnd2
# 1 Q0 6jakyj24 25 1.6613999605178833 ru-t-exp-rnd2
# 1 Q0 x05tfkgx 26 1.6608999967575073 ru-t-exp-rnd2
# 1 Q0 bawgldfi 27 1.6603000164031982 ru-t-exp-rnd2
# 1 Q0 3lp54mmu 28 1.6548999547958374 ru-t-exp-rnd2
# 1 Q0 g6udfu2a 29 1.6532000303268433 ru-t-exp-rnd2
# 1 Q0 dwf5vydu 30 1.6497989892959595 ru-t-exp-rnd2

# %%
valid
# Out:
# {'74c69z28',
#  'hwow5eie',
#  '3oo9u8k8',
#  'p9r733t4',
#  'zlupioxp',
#  's2g5xqtz',
#  'dimdlzwc',
#  'yoxzf1yx',
#  '6e2urzjm',
#  'u9kv4113',
#  'fxlbx84w',
#  '6oca1mrm',
#  'ujo72w06',
#  'twwqo66v',
#  'zqsi6k4q',
#  'e00koo91',
#  'qmo3o8cg',
#  '6x39kaym',
#  'p39caig9',
#  'b49q7944',
#  'h7ffv0xb',
#  'n950aw6u',
#  'zp7v1s9s',
#  'yhzo0qqx',
#  'f15rvjok',
#  'hdc509ww',
#  'gbmjuhgv',
#  '9lkfjvwo',
#  'ptuqsq0q',
#  'vbqjgjah',
#  'pgl7aebd',
#  '218pgsd6',
#  '4rhlkhji',
#  'mneil7gn',
#  'ftsmf9yh',
#  '5qz12dcu',
#  'j90jc0rj',
#  '3g6uswt9',
#  'n3muqhup',
#  'qye9de5o',
#  'nik7xizn',
#  '5y0guel5',
#  'kko3422g',
#  'ch4pcy21',
#  'ww0c2hac',
#  'p2fjtg8l',
#  't6b3bzq7',
#  'j3h5krys',
#  'tymoeyoo',
#  '03c9rx3o',
#  '4ba4h18s',
#  'b62mk859',
#  'l7iovqmg',
#  'ntjngiem',
#  'a47hcrim',
#  'y4t4uu9l',
#  'y9pzsoqa',
#  'vr5hnzp8',
#  '1udn20wo',
#  '2k1nh74w',
#  'lwx79950',
#  'a4ynxgxz',
#  'l7eq3oeb',
#  'g5zdtqnb',
#  'hx51zg4a',
#  'np78ybqs',
#  'uq2gvye9',
#  'wf0zbd0j',
#  'agnmfkoq',
#  'h7wp91r8',
#  'x672pd0y',
#  'c9ts2g7w',
#  'y2tcqh16',
#  'jm60nxc2',
#  'tm7krxxw',
#  'gpabfr9o',
#  '0cxdtr7r',
#  '9ci5ukh5',
#  '3lfl34y9',
#  'xmao6ce4',
#  'hhtaig9d',
#  'ad017zsj',
#  'qolzdwd8',
#  'uxmqlx4y',
#  '02b714lm',
#  'la0hosa4',
#  '1p3zelv1',
#  '8rk2mekw',
#  'wy6yyxf8',
#  'twg2ovv0',
#  '065xbga7',
#  '9iv1krak',
#  'chhemr7s',
#  '2rrlt5z9',
#  'njw33snx',
#  'sr08uhlg',
#  'p05a8zjy',
#  'dsfb97o3',
#  'fn7l93wh',
#  'yoe2bsdo',
#  'qk27wgmd',
#  '9dwpnvxf',
#  'fyncpmal',
#  '48mtdwuv',
#  'sggoz7n8',
#  '19ueli6e',
#  '7ehvcubd',
#  'c7khkkcj',
#  '2dm3rwyk',
#  'eedynopo',
#  '9oyn44xh',
#  '8rj4d7hs',
#  '16032h3d',
#  'k6ovqpsn',
#  'mr22gepe',
#  'py2awuav',
#  'l3qp0n9f',
#  'h46p2oj4',
#  'pjqxhks4',
#  '4quslil0',
#  'ai5tib7h',
#  'xvl715h2',
#  '70vsfffu',
#  't78svobg',
#  'xwa2r8yp',
#  '9dm493sn',
#  '9pcfgi8m',
#  'fsuhj0n6',
#  '3s8o774l',
#  'f4vji9ae',
#  '5i0w74q4',
#  'iaj6xgbm',
#  '4bkemil0',
#  'mtcalbo5',
#  'tc4vulou',
#  'v60k0qa2',
#  'wxkhtrxg',
#  '9htqw5jp',
#  'wwq0sd2r',
#  '4keq0c6u',
#  '8xo6sdcq',
#  'g23cr5vf',
#  'k09j0t98',
#  'xl2u8asv',
#  '3nuw0ymo',
#  'rt7gqiev',
#  '9r62ffew',
#  'z0532g1b',
#  'v52lyh5o',
#  '5qkayfc5',
#  '5cew3hdh',
#  'fwm7rfps',
#  '4u2h78aa',
#  '3rbjwjxu',
#  '41ogljo8',
#  '51bl9n7w',
#  'ct8xyntw',
#  '1d0olfki',
#  '6yfj4co0',
#  '8vjsqp2d',
#  'w8aew9vs',
#  'z2h7mjng',
#  'drxpor44',
#  '9r3eldf9',
#  'tzpe6zwm',
#  'dj47n0up',
#  'zrv9fjgn',
#  'umyxscxn',
#  'pqpyncs0',
#  '9769ir8d',
#  '05qglt1f',
#  'baby6742',
#  'qylm0koe',
#  'txdc0c3j',
#  'q0ln8a1l',
#  '4mig4ck3',
#  '6mxxh6ha',
#  'dmb42kna',
#  'nlwkje4d',
#  'cuhrfh7u',
#  'godn3ckl',
#  'wggeweth',
#  'fp8e7xbm',
#  's04e6po9',
#  'vw9kqzzz',
#  '6yhw9ujx',
#  'vpbdtnyl',
#  'gm88jqvl',
#  'd36aucw2',
#  'w2etygxa',
#  'r0r5of4l',
#  'lfhy70b5',
#  'n92j9y0j',
#  'sxux2ujo',
#  'x0nsb759',
#  'y9l336oi',
#  '2agi21ns',
#  '4lhh3du0',
#  'kgwxvi2h',
#  '322ykerb',
#  'fgl4g7oo',
#  'viwzj99g',
#  'wld24sfy',
#  'vds27ejv',
#  '5dqhhzff',
#  'u91gfw4b',
#  '5pmp33d0',
#  'n78fga3r',
#  'luayiig9',
#  '1ia7vrcu',
#  '3hzkbr0z',
#  'g9t2vog1',
#  'glogkvqb',
#  'uwk05say',
#  'v891bc3i',
#  'p3y79jrb',
#  '72hh21ag',
#  'bcfkosyj',
#  '12dee0lv',
#  '0mjizsoo',
#  'kfkumsux',
#  '2cv7cs48',
#  '8tcw3cll',
#  '3z97ruir',
#  'onyoh6lo',
#  'xwtz8a93',
#  'me04brw1',
#  'w9ev4iy9',
#  's75wn5pr',
#  'zgdxjwes',
#  '84z2te42',
#  'r5n3h2vc',
#  'l6pw3lch',
#  'ns32sje1',
#  'gfumqmku',
#  'mzr1y9zm',
#  'drq8g229',
#  'jw20mrcy',
#  'k0vda7fy',
#  'vbs6hn3a',
#  'jrhqh493',
#  'y518l7r0',
#  '99vw735a',
#  'a71k778s',
#  'cozpxzjc',
#  '7rdzrdw6',
#  'bedfwdyt',
#  'lfv0ypjv',
#  '6mysng0t',
#  'cwv1l03u',
#  'ipeup5mp',
#  'bottcymx',
#  'rpkoz2p9',
#  'x11ipr87',
#  'u2w2bb2p',
#  'vj6fb7a6',
#  'gubekyum',
#  'utdk91iq',
#  'jy3km0fr',
#  '22hbu82q',
#  '0iwm3raw',
#  '1dc46btc',
#  'w0cjo5pa',
#  'k9r1msud',
#  's8j78naz',
#  'zbmzjsvs',
#  'jnz5by5w',
#  'qfdgirku',
#  'sjyrr2bn',
#  'fhwjk6xu',
#  'oean0n3k',
#  'pdaowkop',
#  'sxo6xyl8',
#  't54zftal',
#  'c8b2eea9',
#  '98dvj7lw',
#  'cq6mivr9',
#  'e14cbd1o',
#  'lk9kwilr',
#  'k1p7fo0e',
#  'hh01avfz',
#  'jh7a8lla',
#  'xvodrh91',
#  '1ca0jozs',
#  'rq682r9a',
#  'wkntj7k8',
#  '5sgl3s5l',
#  '1w2f7ozv',
#  '2xt67nje',
#  '6g4as8k8',
#  'zk0u366n',
#  'iivygo4d',
#  'cinkcrnu',
#  'uf7wiz5i',
#  '0i1wwyt3',
#  '4yardtss',
#  'x4oqybge',
#  'dxc0568j',
#  '20tlavgm',
#  '3zibrp5m',
#  'u0w518yg',
#  '2qcp13dt',
#  'dyfvg2eq',
#  '5op2m7pu',
#  'qo5h18ui',
#  'rt5kmv4g',
#  'y885ic8j',
#  'y7b0u82k',
#  'kbihjy2b',
#  'iogs1qke',
#  'ofv6h6az',
#  '148qrvg0',
#  'hi38itc9',
#  'pzuonboo',
#  'i64q5d26',
#  'j5hggp99',
#  'nnbrp3oo',
#  '5cbieb2n',
#  'o3hibw1h',
#  '04p0c4jt',
#  'jys8vod1',
#  'sqhyy6hj',
#  'vnxzmjvx',
#  'awc2pr4q',
#  'p8wm6j28',
#  'sqtrsgvd',
#  'c57impca',
#  '0j5eebym',
#  'ayjud479',
#  'vc6neqew',
#  '158ktbyw',
#  'dsysiefx',
#  'i2mafyzi',
#  'p5sig1en',
#  'zkqayw45',
#  'e7xnugdd',
#  'mn04q582',
#  'csao3flr',
#  '13revo71',
#  'acg4i52a',
#  '5yvburwy',
#  'h6byo95z',
#  'ljomd6zn',
#  'wewaf7ve',
#  'y9sc61b5',
#  '8w9m1d22',
#  'w2efsshj',
#  'l3gmf5ws',
#  'f6o6owg3',
#  'zloqok8o',
#  'ibfcfdcw',
#  'r03j5u18',
#  'ltp7iv1z',
#  'q48gjygy',
#  'ykmp4ven',
#  'igiueg3g',
#  'etc44ma6',
#  'b9oenhez',
#  'fdh54pqu',
#  'tc3sdx9e',
#  'h899xkfy',
#  'zlzi9197',
#  'owhx6k4t',
#  'udykdi44',
#  'n87t254d',
#  'r55fe25x',
#  'huz0tpmi',
#  'zetj7mxz',
#  '9o0xbmme',
#  '6i4lukbu',
#  '8j8zfv91',
#  'obwtd33y',
#  '76fv82yh',
#  'r6ncxavu',
#  'b0cmyzg7',
#  'vgnxhksv',
#  'te7vpcu4',
#  '04jbodmf',
#  '0vprzqoj',
#  'i4q0ljb0',
#  'y6p1oxnq',
#  'xekv4fl9',
#  'yhw169ey',
#  'fhy2z49t',
#  'sl3w5my1',
#  'nny7dog3',
#  'qkks7f2g',
#  '7ow1jja4',
#  'z13yy5t6',
#  'a1mcnta5',
#  'j5bc042j',
#  'uq4eobf0',
#  '08j87r2u',
#  '55tpl7g8',
#  '8d87r39z',
#  'ohkjheat',
#  'g9ev443o',
#  'r0couv6a',
#  'y6ttu9wz',
#  '12qujq0l',
#  'dm6te7nw',
#  'imyfo83x',
#  'wyrg0nq8',
#  '5czqwdwl',
#  '5ts3kk10',
#  '8iqpak2d',
#  'zu4yvn5e',
#  'lgzdk2ep',
#  'ekwshn6a',
#  'v08kag9w',
#  'hncf2qe8',
#  'auqy0767',
#  'uvjriyx1',
#  '9py3w2j6',
#  'l8wj6dsy',
#  'xw7627x9',
#  'r9znjkfo',
#  'f5r82fnb',
#  '03s4zp4q',
#  'qrt65zjj',
#  'd359usvp',
#  '0n5bxp93',
#  'to7wcz5k',
#  'whbkh30a',
#  '6950p8i9',
#  '0nervns8',
#  '02bjl5zo',
#  'ki9f6ssk',
#  'h55l3lvp',
#  'dnxdamsu',
#  'jjpz5smk',
#  '99123nrx',
#  'lug3oqk9',
#  'mizygp4j',
#  'o9qtotlm',
#  'owwi99m8',
#  'qfv8ifvl',
#  'vsxd2h6v',
#  'owbv8ua4',
#  'qutgun1q',
#  '2cy5nv6p',
#  '2xrdv92m',
#  'h3mdrikn',
#  '28mi8go0',
#  '6b6ffsk6',
#  '5lg2c71v',
#  'y7g8z7sk',
#  '88t68k6o',
#  'jixj5bid',
#  'guopjqy7',
#  'miflrobg',
#  'ib4kq2ml',
#  'm0y0fi8m',
#  'we6atutg',
#  '2601n7a9',
#  '0jfvik7w',
#  'yo3cp5vs',
#  'dq39j0dl',
#  'f8uvhstb',
#  'kj12ffef',
#  'lquhmru1',
#  'ta6v9gr0',
#  'ru8xqqj4',
#  'yetdnv6j',
#  '2g6owogs',
#  'ud1n9wyj',
#  'mtjs9zv9',
#  'z9nb8cwt',
#  '6lj444qd',
#  '62qe4fb0',
#  'nyxdfobe',
#  'm3m3t4oy',
#  'xsowwitf',
#  '3gjpqyfw',
#  '8s2ch0l3',
#  'he93c8my',
#  'r17qhfsj',
#  'hry22uf5',
#  'c732txfd',
#  '5bi2q3jj',
#  '2ngwjp3r',
#  '9hf1mu3o',
#  'dw56h8vj',
#  '2rac6nql',
#  '0t28p4g6',
#  'hqlh498d',
#  'qv8ycdhe',
#  'nigjisgy',
#  'rlvk6bcx',
#  '83r28gu8',
#  'dwhu5zca',
#  'sogsxmio',
#  'd9q7zkog',
#  'x9ubqnb5',
#  '01nuj0lk',
#  '2imxd8dy',
#  '5htj2qsw',
#  '5nhtuya7',
#  '1v6kswm6',
#  'cs8sbljk',
#  'pyfeft97',
#  'vqpkmv6e',
#  'q73xuk68',
#  '710c7sx9',
#  '0a20s62q',
#  'p030li19',
#  'j1p52wyn',
#  'u3xhqjqw',
#  'xtjggo4e',
#  'ntikbuer',
#  'gyr8k4j2',
#  'r39ixsk8',
#  'wm6yey1v',
#  'ipn5jl1f',
#  't4ns3syl',
#  '2my86ums',
#  '6zu44fn2',
#  'cnonx8p0',
#  'rdzax3am',
#  'x6s34z1s',
#  'yesxg84u',
#  'hppjo7nu',
#  '703g31e5',
#  'qjke8d6n',
#  '3a1qde41',
#  'mjbuzl07',
#  'nvs6wso3',
#  'mae0rxi2',
#  'ret6iq3o',
#  'xqs2iz25',
#  'xfoy3i7d',
#  'f4spnfi0',
#  '6r25jl11',
#  'br8oczw5',
#  '8opigfsg',
#  '1ecdj314',
#  'x0bio5bl',
#  'y8wx6r5w',
#  'eix09xn1',
#  'hsufdxlc',
#  'm855sd72',
#  '70exgy3h',
#  'cfg9adrh',
#  'rh8fos6i',
#  '2zanmu5z',
#  'eeon1do2',
#  'le0ogx1s',
#  'myw79tsp',
#  'dnw1h3z2',
#  'nycdhdsd',
#  'drvr1swh',
#  'rgo5sj5i',
#  '7v4y02j6',
#  'vtt1k6ph',
#  't6n95laz',
#  'sxtcmbqc',
#  'fphchbw5',
#  'ttgcex6b',
#  'jvr1t6t2',
#  'q5tqiny4',
#  'bggo5e9t',
#  '9fr0m92p',
#  'eflp6p4v',
#  'td8nz62y',
#  '6gbdlw8h',
#  'ci5xftqm',
#  '5hrydciz',
#  '8q5ondtn',
#  '8zpiecqm',
#  'nrafykfp',
#  'dq5132me',
#  'tvz4ze8g',
#  'iyuca9lv',
#  'pz1l08bj',
#  'b7jqx7fi',
#  'zzys31e9',
#  'cmi0yf58',
#  'ddz53zin',
#  'wf8uibvv',
#  'gb85odqv',
#  'wouunr5s',
#  'yt5cscf1',
#  'cb0xe1sw',
#  'otyhpukl',
#  'ugd8kkor',
#  'khilfcyv',
#  'mltgybls',
#  'anfbkmy6',
#  '84hvcsyu',
#  'b8l71xbq',
#  'yrqcyboo',
#  '36f6amze',
#  'zyf0gswm',
#  'zrqp24gb',
#  'f4p00yaw',
#  'b8nam316',
#  't5gj0k54',
#  '2yl7kl7b',
#  '6hdoap81',
#  '9ai4403g',
#  'h03n2odu',
#  '51iutuxm',
#  'c9zya2t7',
#  'k5xpirfz',
#  'pu1wmrlh',
#  'rhpvd7ud',
#  '3ns2hhjl',
#  'ap0zwzzl',
#  'vfr73og9',
#  'swwz4kzd',
#  'z5sn1czf',
#  'x7yuxblo',
#  'wdvt0chl',
#  '3a9vjpvn',
#  't2xugb8l',
#  'txk3j2b7',
#  '19ec0trp',
#  'yxttl3gh',
#  '91dypqu1',
#  'ci5lpo7j',
#  'ipoelk4h',
#  'crrv37jz',
#  'a1q8dvu7',
#  '5kckzaqx',
#  'ziijht2j',
#  'prmf9yob',
#  '0r99rtay',
#  't4dafq67',
#  'v862bw1o',
#  'ecvpmuz3',
#  'ewowkq8o',
#  'cx0sa7re',
#  'rkxlm4v9',
#  'el54v8ic',
#  'emdyfh1l',
#  'hgqwwckt',
#  '010zkqhb',
#  'j8tes6q5',
#  '9ujoy4lo',
#  'y3hgnb6u',
#  'm4pterq5',
#  '8zxl48af',
#  'n76iea5g',
#  'sl5zy8nj',
#  'p2dbhw79',
#  'emtrrwpv',
#  '92axhiaq',
#  '76ylloqx',
#  'ak22ykbp',
#  'd9sii5a1',
#  'r4hfwae1',
#  'my88hvv5',
#  'cv3qgno3',
#  'tbqlxdnf',
#  'dhdk1mv0',
#  '925ydjv2',
#  'm3rlifgf',
#  'ble8gn1l',
#  'twkw0agj',
#  'vufv17f1',
#  'b378ppd8',
#  '4ftedh1a',
#  '05u4t67u',
#  'igmb2yfe',
#  'md5mhxvf',
#  'ekmuz4ug',
#  'gcgpa2nx',
#  '9n0ywxk4',
#  'b1ndbct4',
#  '2ohyksde',
#  'l7nra4cq',
#  's3jnwuzt',
#  '37vyazby',
#  'gs3r6en8',
#  '1dn7at6k',
#  '1mowsbjy',
#  'vzbh457k',
#  'z8thv6ar',
#  'lr88hhyh',
#  '6kbdxhxv',
#  'vqtwas4x',
#  'uuojma33',
#  'f1rh4rfa',
#  'd79twl34',
#  'dkdg3n7j',
#  'y27aa1b6',
#  'j4udjq3v',
#  '3jprs5q2',
#  'djs4j6cm',
#  'pyy1ega9',
#  '8picmo53',
#  'exo15zv8',
#  'o6v37h8w',
#  '4hvfyxsd',
#  'yygerqj9',
#  'b3vtf7sd',
#  'ok19r7w4',
#  'pqa9zue8',
#  'jm2xpn1w',
#  '0n37jgjv',
#  'v1f6dx3e',
#  '1qwbkg9o',
#  '1enb5qcu',
#  'rpkyycru',
#  'snzmb0yn',
#  '2ob62k15',
#  'rhkzwlf0',
#  '4z5jxxf2',
#  '6zlizqe9',
#  'upsc9cf8',
#  'vui2ugot',
#  'ihl7xnps',
#  '5mtmkpfv',
#  'cgcaerjy',
#  'y0wf456f',
#  '0v17xscr',
#  'bueau3lw',
#  've1fgnyg',
#  'b9etg0p8',
#  'kk8fn04s',
#  'hx7ktq8j',
#  'st27v3st',
#  'xnrnyq8y',
#  'nu0fuuxp',
#  '1u10lpx2',
#  'nkr14gw6',
#  'li6xz9gt',
#  'iv8k03z8',
#  'mcg3szl9',
#  'rwvf4ym3',
#  'elhwx8ui',
#  '1pm27u49',
#  'fwdpzv85',
#  'wtw6jozx',
#  '2nddhxxo',
#  'yhoyu4fw',
#  '3aydbdmu',
#  '6zvstml1',
#  'y7t47t7a',
#  '4dabwcfi',
#  'md2w79i5',
#  '452tu4ss',
#  '3pi2aimv',
#  'bfd5ts44',
#  'hs7sw4mc',
#  'q5bfwyqw',
#  'xxsmb9go',
#  '8prn86g6',
#  'xy4uk8zg',
#  '1yoilmcw',
#  'k531q3ir',
#  '4xytv87r',
#  'saljl8sv',
#  'wqdszb22',
#  '7e188tbq',
#  '5icm9pjk',
#  'o0mhzx3g',
#  'g4puurhk',
#  'p5aj5k2g',
#  'ksxqmmgw',
#  'do6i6ymq',
#  'kf1fs1ka',
#  '0bwf8f1i',
#  'emi989ys',
#  'v1sguyjv',
#  'wtax0yqp',
#  'tmhguzsx',
#  '5abus746',
#  'rh1ad6bv',
#  'wmftyxmp',
#  'cdna0hk4',
#  '09fl2k0h',
#  '211ttwtc',
#  '7xj27r98',
#  'x91sayto',
#  '1tscs3iq',
#  'jwrv3e6j',
#  'ubg3mj4u',
#  'uywz5nqw',
#  'a4d7eqa0',
#  'r01erhp3',
#  'st9biegt',
#  'zd8dhqlf',
#  '61gajzlr',
#  '5cwb5g3h',
#  'ukixf3l5',
#  'fugb778l',
#  '399rq84t',
#  '73dsc6q3',
#  'czgk6hzy',
#  'o8j17zzs',
#  'pfxkwotf',
#  'lbk7hxy2',
#  'v76a1036',
#  'h98zw4of',
#  '6a7krfpb',
#  'b0y7kvph',
#  's7ec6f9i',
#  'yvgzkt8a',
#  'pdrjrllp',
#  'wr7vrild',
#  'vcyej0zq',
#  'jpzvjl0i',
#  'ujtb7xgz',
#  'az4ov2ue',
#  'fqw366x8',
#  'jjm7y07m',
#  '8twjdyjc',
#  'jccfhizf',
#  '6u0osc4n',
#  'b3ui95vx',
#  'hahqwt5x',
#  '1kuggdzj',
#  'bc0un6kb',
#  'v1lvzzi4',
#  '5kf4nvem',
#  '278wc4dy',
#  '8gp9mjen',
#  'bxijla09',
#  'ucp9079x',
#  'wc9gut0y',
#  'vq0p5d2x',
#  'fxqyqolb',
#  'bw2go1on',
#  'nb8mfh7z',
#  '0l1l7tdl',
#  'e0plqpgb',
#  'sg6vnur0',
#  'px6dfzz4',
#  't89df3fd',
#  'r044iimd',
#  'b25mi0sp',
#  'dhfl92et',
#  'mch4wbui',
#  'pu1fetq7',
#  'gy8f1oyt',
#  'yl7jdarm',
#  'dw0h2hlc',
#  'jiohiiud',
#  'c6ft2cyf',
#  't2qpisrn',
#  'ghrlj6b2',
#  'zfpcuhpy',
#  'aohmw1ol',
#  'nit5v1wg',
#  'yup3rb7r',
#  'iumjgo4w',
#  'x89inuzx',
#  '4ffbqpkk',
#  'pd0tk6hq',
#  'h0q1m3ed',
#  '58p5b2vw',
#  'l4288mxw',
#  '9i9dlx2y',
#  'wrg43sal',
#  'xox2nc81',
#  '0z2nj2ew',
#  'zamdcxk6',
#  '11xyqp0h',
#  'xq35tewt',
#  '3r244w9a',
#  '3ty7rqkd',
#  'wl2tyb0k',
#  'wy48jhsb',
#  'f6lfykot',
#  'vsmto57f',
#  'muf6mqoy',
#  'wzc4f6m2',
#  'hi4b5ppx',
#  '2jd7aa2d',
#  '8w5elfro',
#  'ucu87rsl',
#  'ush1ynm4',
#  '61cyofjx',
#  'kxjeallw',
#  'li33am1r',
#  'og2y86dq',
#  'nuxtxzox',
#  '4p398ewl',
#  '10dvik60',
#  'x636ux34',
#  '9b11c0od',
#  'dfpb70s7',
#  'xtzmt0nx',
#  '291b7ojc',
#  'n06843iv',
#  'o9zu1mr0',
#  'deykpbv8',
#  'vlns6j0j',
#  'ioof1c9s',
#  'if63700x',
#  'qy6zs7ik',
#  'ptftao1d',
#  '5silkbgb',
#  'hrug9k84',
#  'efk5pzov',
#  'mvu97jsu',
#  'yq7ie643',
#  '4dowkeqq',
#  '2mgitoou',
#  '3sjx0xus',
#  '7bgerq3r',
#  'xncyu3i1',
#  '9djt90wi',
#  '28igib4l',
#  'ous5jtct',
#  'ovlrxrjr',
#  'wm2eyaam',
#  'myb397i3',
#  'iyxjpbly',
#  'c1lh0896',
#  'g1eyfrmc',
#  'hobmv0x2',
#  'wgs69cu6',
#  '44l35tqv',
#  '7rvv2kzk',
#  'sc65vp0j',
#  '75v2qt1w',
#  'qu4zin3o',
#  'a37oyrtc',
#  '0ybn2igj',
#  'gvdxs72b',
#  'a3n1fd6j',
#  '9gu8eo27',
#  '3lwrn2fi',
#  'lze5g31s',
#  'kon3ooo3',
#  'j0n14tqq',
#  '2twtrg3d',
#  'rasjpg8v',
#  'adiqqmxh',
#  'y95anisa',
#  'umttnp1g',
#  '1s0exznp',
#  'imtttzvr',
#  '77hs0bp9',
#  'jna496x7',
#  'h6xjudm0',
#  'du51e5cv',
#  'ac08um4i',
#  'cxtqqicm',
#  'n1div0jy',
#  'zuw4xo9j',
#  'z8db3qi6',
#  '7nad825d',
#  '7p8mw6e6',
#  'ns8fmtkp',
#  '7rs4jtfh',
#  'ts91ivwf',
#  'bim76jna',
#  'o2hx667i',
#  'huw7pnzu',
#  'jxgd1yc4',
#  '3mj670c2',
#  'lotyldfd',
#  'tv1vmr4q',
#  'oots4fe4',
#  'zc0x6hqp',
#  'oac8uday',
#  'dzqkdlzc',
#  'ajwanlec',
#  '223l6tgo',
#  'ek4sz62e',
#  'gd53s4dv',
#  '5cxaiw4k',
#  'zpwqunl5',
#  '3n9dvawa',
#  '9mmktlhf',
#  'lplodn60',
#  '82syul80',
#  '9puxj1h9',
#  'fqu54j4h',
#  'hrtih5o4',
#  'g6lcpo3q',
#  'qq9ecrhk',
#  '15rg623y',
#  'fzsczb8m',
#  '3zjczj2a',
#  'jbuuph6w',
#  '55lftxc7',
#  'ewm8potj',
#  'lwjwbks1',
#  's3bly5ky',
#  'g5lr9ctn',
#  'h016xbzb',
#  '1ejzchwa',
#  'wbxnizd4',
#  'dbpw4u17',
#  'ako6p5c3',
#  'cr3nhofk',
#  'umso5uv0',
#  'kkkw3ye6',
#  'ok3px98z',
#  '3kfy36hg',
#  'xta97neu',
#  'bhmnvq7c',
#  'jiins3m0',
#  'latbpwpw',
#  '9fm2gpxx',
#  '0wga7ill',
#  ...}
